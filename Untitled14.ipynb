# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
dp_colm = pd.read_csv('/content/drive/MyDrive/activity1.1/movies_metadata.csv',
                      usecols=['imdb_id', 'genres', 'overview', 'budget', 'runtime', 'release_date'],
                      index_col='imdb_id')

# %%
dp_colm.head()
# Out:
#              budget                                             genres  \
# imdb_id
# tt0114709  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# tt0113497  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# tt0113228         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# tt0114885  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt0113041         0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                                     overview release_date  \
# imdb_id
# tt0114709  Led by Woody, Andy's toys live happily in his ...   1995-10-30
# tt0113497  When siblings Judy and Peter discover an encha...   1995-12-15
# tt0113228  A family wedding reignites the ancient feud be...   1995-12-22
# tt0114885  Cheated on, mistreated and stepped on, the wom...   1995-12-22
# tt0113041  Just when George Banks has recovered from his ...   1995-02-10
#
#            runtime
# imdb_id
# tt0114709     81.0
# tt0113497    104.0
# ...

# %%
df_rename = dp_colm.rename(columns={
    'imdb_id': 'IMDB ID',
    'genres': 'Genres',
    'overview': 'Overview',
    'budget': 'Budget',
    'release_date': 'Date',
    'runtime': 'Runtime'
})

# %%
df_rename.head()
# Out:
#              Budget                                             Genres  \
# imdb_id
# tt0114709  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# tt0113497  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# tt0113228         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# tt0114885  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt0113041         0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                                     Overview        Date  \
# imdb_id
# tt0114709  Led by Woody, Andy's toys live happily in his ...  1995-10-30
# tt0113497  When siblings Judy and Peter discover an encha...  1995-12-15
# tt0113228  A family wedding reignites the ancient feud be...  1995-12-22
# tt0114885  Cheated on, mistreated and stepped on, the wom...  1995-12-22
# tt0113041  Just when George Banks has recovered from his ...  1995-02-10
#
#            Runtime
# imdb_id
# tt0114709     81.0
# tt0113497    104.0
# ...

# %%
df_drop=df_rename.drop(columns=['Genres'])
df_drop.head()
# Out:
#              Budget                                           Overview  \
# imdb_id
# tt0114709  30000000  Led by Woody, Andy's toys live happily in his ...
# tt0113497  65000000  When siblings Judy and Peter discover an encha...
# tt0113228         0  A family wedding reignites the ancient feud be...
# tt0114885  16000000  Cheated on, mistreated and stepped on, the wom...
# tt0113041         0  Just when George Banks has recovered from his ...
#
#                  Date  Runtime
# imdb_id
# tt0114709  1995-10-30     81.0
# tt0113497  1995-12-15    104.0
# tt0113228  1995-12-22    101.0
# tt0114885  1995-12-22    127.0
# tt0113041  1995-02-10    106.0

# %%
del df_drop['Date']
df_drop.head()
# Out:
#              Budget                                           Overview  \
# imdb_id
# tt0114709  30000000  Led by Woody, Andy's toys live happily in his ...
# tt0113497  65000000  When siblings Judy and Peter discover an encha...
# tt0113228         0  A family wedding reignites the ancient feud be...
# tt0114885  16000000  Cheated on, mistreated and stepped on, the wom...
# tt0113041         0  Just when George Banks has recovered from his ...
#
#            Runtime
# imdb_id
# tt0114709     81.0
# tt0113497    104.0
# tt0113228    101.0
# tt0114885    127.0
# tt0113041    106.0
