# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
filename = '/content/drive/MyDrive/activity1.1/movies_metadata.csv'
df = pd.read_csv(filename)
# Out:
# <ipython-input-4-7f8c5697df6f>:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)

# %%
df.head(10)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
# 9  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
# 5  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 6  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 7  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 8  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 9  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                        homepage     id    imdb_id  \
# 0          http://toystory.disney.com/toy-story    862  tt0114709
# 1                                           NaN   8844  tt0113497
# 2                                           NaN  15602  tt0113228
# 3                                           NaN  31357  tt0114885
# 4                                           NaN  11862  tt0113041
# 5                                           NaN    949  tt0113277
# 6                                           NaN  11860  tt0114319
# 7                                           NaN  45325  tt0112302
# 8                                           NaN   9091  tt0114576
# 9  http://www.mgm.com/view/movie/757/Goldeneye/    710  tt0113189
#
#   original_language               original_title  \
# 0                en                    Toy Story
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
# 5                en                         Heat
# 6                en                      Sabrina
# 7                en                 Tom and Huck
# 8                en                 Sudden Death
# 9                en                    GoldenEye
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
# 5  Obsessive master thief, Neil McCauley leads a ...  ...   1995-12-15
# 6  An ugly duckling having undergone a remarkable...  ...   1995-12-15
# 7  A mischievous young boy, Tom Sawyer, witnesses...  ...   1995-12-22
# 8  International action superstar Jean Claude Van...  ...   1995-12-22
# 9  James Bond must unmask the mysterious head of ...  ...   1995-11-16
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5  187436818.0   170.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 6          0.0   127.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 7          0.0    97.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 8   64350171.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9  352194034.0   130.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
# 5  Released                           A Los Angeles Crime Saga
# 6  Released  You are cordially invited to the most surprisi...
# 7  Released                             The Original Bad Boys.
# 8  Released                         Terror goes into overtime.
# 9  Released               No limits. No fears. No substitutes.
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
# 5                         Heat  False          7.7     1886.0
# 6                      Sabrina  False          6.2      141.0
# 7                 Tom and Huck  False          5.4       45.0
# 8                 Sudden Death  False          5.5      174.0
# 9                    GoldenEye  False          6.6     1194.0
#
# [10 rows x 24 columns]

# %%
df[['budget']].head()
# Out:
#      budget
# 0  30000000
# 1  65000000
# 2         0
# 3  16000000
# 4         0

# %%
df[['budget', 'genres', ]].tail()
# Out:
#       budget                                             genres
# 45461      0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462      0                      [{'id': 18, 'name': 'Drama'}]
# 45463      0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464      0                                                 []
# 45465      0                                                 []

# %%
df['budget'].head()
# Out:
# 0    30000000
# 1    65000000
# 2           0
# 3    16000000
# 4           0
# Name: budget, dtype: object

# %%
type(df['original_language'].head())
# Out:
# pandas.core.series.Series

# %%
df['overview', 'release_date']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('overview', 'release_date')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-d7ba1f4cf8f4> in <cell line: 1>()
# ----> 1 df['overview', 'release_date']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: ('overview', 'release_date')

# %%
df['overview']
# Out:
# 0        Led by Woody, Andy's toys live happily in his ...
# 1        When siblings Judy and Peter discover an encha...
# 2        A family wedding reignites the ancient feud be...
# 3        Cheated on, mistreated and stepped on, the wom...
# 4        Just when George Banks has recovered from his ...
#                                ...
# 45461          Rising and falling between a man and woman.
# 45462    An artist struggles to finish his work while a...
# 45463    When one of her hits goes wrong, a professiona...
# 45464    In a small town live two brothers, one a minis...
# 45465    50 years after decriminalisation of homosexual...
# Name: overview, Length: 45466, dtype: object

# %%
df['original_title'].value_counts()
# Out:
# Hamlet                 8
# Alice in Wonderland    8
# Les Misérables         7
# Cinderella             7
# Macbeth                7
#                       ..
# 거미숲                    1
# What Goes Up           1
# 12th & Delaware        1
# Wonder Bar             1
# Queerama               1
# Name: original_title, Length: 43373, dtype: int64

# %%
df_filter=df['budget']=='6000000'
df_filter.head()
df[df_filter].head()
# Out:
#      adult belongs_to_collection   budget  \
# 49   False                   NaN  6000000
# 177  False                   NaN  6000000
# 325  False                   NaN  6000000
# 352  False                   NaN  6000000
# 366  False                   NaN  6000000
#
#                                                 genres  \
# 49   [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 177  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 325  [{'id': 80, 'name': 'Crime'}, {'id': 27, 'name...
# 352  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 366  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                               homepage     id    imdb_id  \
# 49   http://www.mgm.com/#/our-titles/2083/The-Usual...    629  tt0114814
# 177                                                NaN   2293  tt0113749
# 325                                                NaN  25066  tt0114609
# 352    http://workingtitlefilms.com/film.php?filmID=59    712  tt0109831
# 366                                                NaN  12280  tt0110771
#
#     original_language               original_title  \
# 49                 en           The Usual Suspects
# 177                en                     Mallrats
# 325                en          Tales from the Hood
# 352                en  Four Weddings and a Funeral
# 366                en                    The Paper
#
#                                               overview  ... release_date  \
# 49   Held in an L.A. interrogation room, Verbal Kin...  ...   1995-07-19
# 177  Both dumped by their girlfriends, two best fri...  ...   1995-10-20
# 325  A strange funeral director tells four strange ...  ...   1995-05-24
# 352  Four Weddings And A Funeral is a British comed...  ...   1994-03-09
# 366  Henry Hackett is the editor of a New York City...  ...   1994-03-18
#
#          revenue runtime                                   spoken_languages  \
# 49    23341568.0   106.0  [{'iso_639_1': 'es', 'name': 'Español'}, {'iso...
# 177    2122561.0    94.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 325   12000000.0    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 352  254700832.0   117.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 366          0.0   112.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#        status                                            tagline  \
# 49   Released       Five Criminals. One Line Up. No Coincidence.
# 177  Released  They're not there to shop. They're not there t...
# 325  Released                                Chill or be Chilled
# 352  Released                  Five good reasons to stay single.
# 366  Released  A behind-the-lines look at work, marriage and ...
#
#                            title  video vote_average vote_count
# 49            The Usual Suspects  False          8.1     3334.0
# 177                     Mallrats  False          6.8      400.0
# 325          Tales from the Hood  False          5.4       33.0
# 352  Four Weddings and a Funeral  False          6.6      654.0
# 366                    The Paper  False          6.1       40.0
#
# [5 rows x 24 columns]

# %%
df['adult'].value_counts()
# Out:
# False                                                                                                                             45454
# True                                                                                                                                  9
#  - Written by Ørnås                                                                                                                   1
#  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.                        1
#  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.        1
# Name: adult, dtype: int64

# %%
df['adult']=='true'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45461    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: adult, Length: 45466, dtype: bool

# %%
interest_filter=df['adult']=='true'
df=df.loc[interest_filter, :]
df['adult'].value_counts(dropna=False)
# Out:
# Series([], Name: adult, dtype: int64)

# %%
df.homepage.head()
# Out:
# 0    http://toystory.disney.com/toy-story
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# Name: homepage, dtype: object

# %%
df.loc[:, ['homepage']].head()
# Out:
#                                homepage
# 0  http://toystory.disney.com/toy-story
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN

# %%
df.loc[:, 'original_title'].head()
# Out:
# 0                      Toy Story
# 1                        Jumanji
# 2               Grumpier Old Men
# 3              Waiting to Exhale
# 4    Father of the Bride Part II
# Name: original_title, dtype: object

# %%
df['original_title'].value_counts()
# Out:
# Hamlet                 8
# Alice in Wonderland    8
# Les Misérables         7
# Cinderella             7
# Macbeth                7
#                       ..
# 거미숲                    1
# What Goes Up           1
# 12th & Delaware        1
# Wonder Bar             1
# Queerama               1
# Name: original_title, Length: 43373, dtype: int64

# %%
mortgage_filter = df['original_language']=='30 Year'
mortgage_filter.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: original_language, dtype: bool

# %%
df.loc[mortgage_filter, :].head()
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.loc[mortgage_filter, :].head()
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['genres'].value_counts()
# Out:
# [{'id': 18, 'name': 'Drama'}]                                                                                                         5000
# [{'id': 35, 'name': 'Comedy'}]                                                                                                        3621
# [{'id': 99, 'name': 'Documentary'}]                                                                                                   2723
# []                                                                                                                                    2442
# [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]                                                                       1301
#                                                                                                                                       ...
# [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}, {'id': 99, 'name': 'Documentary'}]             1
# [{'id': 10752, 'name': 'War'}, {'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}, {'id': 53, 'name': 'Thriller'}]               1
# [{'id': 27, 'name': 'Horror'}, {'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}, {'id': 53, 'name': 'Thriller'}]               1
# [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}, {'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}]                   1
# [{'id': 10751, 'name': 'Family'}, {'id': 16, 'name': 'Animation'}, {'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]       1
# Name: genres, Length: 4069, dtype: int64

# %%
df = df.loc[mortgage_filter, :]
df['id'].value_counts()
# Out:
# Series([], Name: id, dtype: int64)

# %%
df['revenue'].value_counts()
# Out:
# Series([], Name: revenue, dtype: int64)

# %%
df['adult']==0.03
# Out:
# Series([], Name: adult, dtype: bool)

# %%
interest_filter = df['original_title']==0.03
df = df.loc[interest_filter, :]
df['original_title'].value_counts(dropna = False)
# Out:
# Series([], Name: original_title, dtype: int64)

# %%
df = df.loc[mortgage_filter & interest_filter, :]
df
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.Principal Paid
# Out:
#   File "<ipython-input-37-df2010422d5f>", line 1
#     df.Principal Paid
#                  ^
# SyntaxError: invalid syntax

# %%
df = df.rename(columns={'original_title': 'overview',
'release_date': 'revenue',
'runtime': 'spoken_languages'})

df.head
# Out:
# <bound method NDFrame.head of Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, overview, overview, popularity, poster_path, production_companies, production_countries, revenue, revenue, spoken_languages, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]>

# %%
df.columns =['', 'adult',	'belongs_to_collection',	'budget'	,'genres',	'homepage',	'id',	'imdb_id',	'original_language',	'original_title',	'overview',	'...',	'release_date',	'revenue',	'runtime'	,'spoken_languages',	'status',	'tagline',	'title',	'video',	'vote_average',	'vote_count','','']
df.head()
# Out:
# Empty DataFrame
# Columns: [, adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, ..., release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count, , ]
# Index: []
#
# [0 rows x 24 columns]

# %%
df = df.drop(columns=['revenue'])
df.head()
# Out:
# Empty DataFrame
# Columns: [, adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, ..., release_date, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count, , ]
# Index: []
#
# [0 rows x 23 columns]

# %%
del df['original_title']
df.head()
# Out:
# Empty DataFrame
# Columns: [, adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, overview, ..., release_date, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count, , ]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.isna()
# Out:
# Empty DataFrame
# Columns: [, adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, overview, ..., release_date, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count, , ]
# Index: []
#
# [0 rows x 22 columns]
